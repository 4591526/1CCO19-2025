# %% [markdown]
# # **Mi primer código en Python**
#
#
# Luisa Gomez (luisa.gomez@pucp.edu.pe)
#
# https://pcc-interactivo.streamlit.app
#
#
# ## **Objetivos**
#
# * Escribir un código básico en Python
# * Consultar información con `help()`

# %% [markdown]
# ## **Contenidos**
# * Escribe "¡Hola Mundo!" en Python
#     * La función print()
#     * La función help()
#     * Escribir comentarios en Python
#     * Errores en Python
#     * ¿Python detecta tu error antes de ejecutar el código?
#     * Ejercicios

# %% [markdown]
# # **Título**
# ## *SUBTÍTULO*
# ### TEXTO

# %% [markdown]
# ---
# # **Escribe "¡Hola Mundo!" en Python**

# %% [markdown]
# ---
# [Tip]: Para ejecutar el código de Python en la celda de código a continuación, haga clic en la celda para seleccionarla y presionar `CTRL` + `Enter`.
#
# ---

# %%
# Probemos el primer output en Python

print('¡Hola Mundo!')
# Out:
# ¡Hola Mundo!

# %% [markdown]
# ---
# [Tip:] `print()` es una función. En este caso, recibe el string `'¡Hola Mundo!'` como argumento, para indicarle a Python qué debe imprimir como output.
#
# ---

# %% [markdown]
# ### **¿Cómo podemos modificar el código para que muestre tu nombre en lugar de 'Hola mundo'?**

# %%
# Imprimamos nuestros nombres
print("Luisa")
# Out:
# Luisa

# %%
# Imprimamos un número
print("22")
# Out:
# 22

# %%
# ¿Qué sucede si escribimos un número de esta forma?
print(22)
# Out:
# 22

# %% [markdown]
# ---
# [Tip:] `type()`es una función que se usa para saber de qué tipo es un dato u objeto.
#
# ---

# %%
# ¿Qué tipo de dato es?
print(type("22"))
# Out:
# <class 'str'>

# %%
# ¿Qué tipo de dato es?
print(type(22))
# Out:
# <class 'int'>

# %%
print("Bienvenidos al semestre 2025 - II")
# Out:
# Bienvenidos al semestre 2025 - II

# %%
print("Bienvenidos al semestre", 2025)
# Out:
# Bienvenidos al semestre 2025

# %% [markdown]
# ## **La función print()**
#
# Esta función permite mostrar un texto especifico en la pantalla. El texto a mostrar se escribe como argumento de la función.

# %%
# Un argumento puede escribirse con comillas dobles
print("Pensamiento Computacional")
# Out:
# Pensamiento Computacional

# %%
# Un argumento puede escribirse con comillas simples
print('Pensamiento Computacional')
# Out:
# Pensamiento Computacional

# %% [markdown]
# La función print() admite varios argumentos seguidos. En el programa, los argumentos deben separarse por comas.

# %%
# La función print() puede contener más de un argumento
# La coma que separa cada argumento representa un espacio vacío
print("Hola", "Adiós")
# Out:
# Hola Adiós

# %%
# Los espacios vacíos dentro de un argumento también se respetan cuando usamos la función print()
print("Hola Adiós") # el resultado es igual a print("Hola", "Adiós")
# Out:
# Hola Adiós

# %%
# Sin una coma que separe argumentos se interpreta como un solo argumento sin espacio entre ellos
print("Hola" "Adiós")
# Out:
# HolaAdiós

# %%
# Si se busca imprimir un argumento que contiene dos palabras sin espacio entre ellas se mostrará junto
print("HolaAdiós") # el resultado es igual a print("Hola" "Adiós")
# Out:
# HolaAdiós

# %% [markdown]
# Al final de cada print(), Python añade automáticamente un salto de línea.

# %%
# Imprimamos dos argumentos distintos con print() en dos líneas de código
print("Aula")
print("Z104")
# Out:
# Aula
# Z104

# %%
# Agregamos un print() sin un argumento
print("Aula")
print()  # Python respeta el vacío como un espacio en blanco
print("Z104")
# Out:
# Aula
#
# Z104

# %% [markdown]
# Si se quieren separar los argumentos en la salida, hay que incluir los espacios deseados.

# %%
# Se puede agregar un espacio vacío al final del argumento de la primera línea
print("Aula ", end="")
print("Z104") # el resultado es igual a print("Aula", "Z104") o print("Aula Z104")
# Out:
# Aula Z104

# %%
# Se puede agregar un espacio vacío antes del argumento de la segunda línea
print("Aula", end="")
print(" Z104") # el resultado es igual a print("Aula", "Z104") o print("Aula Z104")
# Out:
# Aula Z104

# %%
print("Aula Z104")
# Out:
# Aula Z104

# %% [markdown]
# También se puede ejecutar dos argumentos y especificar un separador.

# %%
# Se puede indicar qué tipo de separador deseas entre los argumentos, estos se imprimiran en vez de indicar un espacio vacío por defecto
print("Hola", "¿Cómo están?", sep="--")
# Out:
# Hola--¿Cómo están?

# %%
print("Hola", "¿Cómo están?", sep=":")
# Out:
# Hola:¿Cómo están?

# %%
print("Hola", "¿Cómo están?", "Bien", sep=": ") # Puedes agregar un espacio vacío al final o al inicio de un argumento, también puedes agregarlo en el separador
# Out:
# Hola: ¿Cómo están?: Bien

# %% [markdown]
# ---

# %% [markdown]
# ## **La función help()**
# Es una función integrada que proporciona información sobre funciones. Es útil para recuperar información sobre diversos objetos de Python.

# %%
help(type)
# Out:
# Help on class type in module builtins:
#
# class type(object)
#  |  type(object) -> the object's type
#  |  type(name, bases, dict, **kwds) -> a new type
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(self, /)
#  |      Specialized __dir__ implementation for types.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __instancecheck__(self, instance, /)
#  |      Check if an object is an instance.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __setattr__(self, name, value, /)
# ...

# %% [markdown]
# **print(*args, sep=' ', end='\n')**
# * Admite argumentos
# * sep: Se inserta una cadena entre los valores; por defecto, un espacio.
# * end: Se añade una cadena después del último valor; por defecto, una nueva línea (\n).

# %%
print("Mundial", 2026, sep="\t", end='\n')
# \n  -> esto indica un salto de línea
# \t -> esto indica una sangría
# Out:
# Mundial	2026

# %% [markdown]
# ---

# %% [markdown]
# ## **Escribir comentarios en Python**

# %% [markdown]
# Además de escribir código, ten en cuenta que siempre es buena idea añadir comentarios. Esto ayudará a otros a comprender tu objetivo (la razón por la que escribiste un fragmento de código). Esto no solo ayuda a que otros lo entiendan, sino que también puede servirte de recordatorio cuando lo revises semanas o meses después.
#
#
# Para escribir comentarios en Python, usa el símbolo **#** antes de escribirlos. **Al ejecutar el código, Python ignorará todo lo que esté después del símbolo # en una línea determinada**.

# %%
# Escribamos un comentario

print('Facultad de Ciencias y Artes de la Comunicación') # Esta línea imprime un string

print('Bienvenidos')
# Out:
# Facultad de Ciencias y Artes de la Comunicación
# Bienvenidos

# %%
# ¿Qué carreras se imprimen?

print("Publicidad")
# print("Periodismo")
print("Comunicación Audiovisual")
print("Comunicación para el Desarrollo")
# Out:
# Publicidad
# Comunicación Audiovisual
# Comunicación para el Desarrollo

# %% [markdown]
# ## **Errores en Python**

# %% [markdown]
# Todos cometemos errores. Para muchos tipos de errores, Python le dirá que ha cometido un error al darle un mensaje de error. Es importante leer los mensajes de error detenidamente para comprender realmente dónde se cometió un error y cómo puedes corregirlo.

# %%
# Ejecutamos un string con un mensaje de error

frint("Hello, Python!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1260571934.py in <cell line: 0>()
#       1 # Ejecutamos un string con un mensaje de error
#       2
# ----> 3 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined

# %% [markdown]
# El mensaje de error te dice:
#
# * dónde ocurrió el error, y
# * de qué tipo de error se trata

# %%
# Corregimos el código
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
# # ¿Cuál es el error aquí?

print("Hello, Python!)
# Out:
#   File "/tmp/ipython-input-1136332329.py", line 3
#     print("Hello, Python!)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# Corregimos el código
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# ## **¿Python detecta tu error antes de ejecutar el código?**

# %% [markdown]
# Python es lo que se denomina un `lenguaje interpretado`. Por su parte, los lenguajes compilados (C++, Java, entre otros) examinan todo el programa en el momento de la compilación y pueden advertirle sobre toda clase de errores antes de la ejecución. Por el contrario, Python interpreta línea por línea a medida que lo ejecuta. Python dejará de ejecutar todo el programa cuando encuentre un error.

# %% [markdown]
# Intente ejecutar el código en la celda a continuación y vea qué sucede:

# %%
# Recorremos los siguientes strings para ver el orden de ejecución

print("Esto se ejecutará")
frint("Esto tendrá un error")
print("Esto NO se ejecutará")
# Out:
# Esto se ejecutará
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1825474855.py in <cell line: 0>()
#       2
#       3 print("Esto se ejecutará")
# ----> 4 frint("Esto tendrá un error")
#       5 print("Esto NO se ejecutará")
#
# NameError: name 'frint' is not defined

# %% [markdown]
# ## **Ejercicios**

# %% [markdown]
# a. En la siguiente celda de código, use la función `print()` para imprimir una frase.

# %% [markdown]
# b. Ahora, mejoremos el código con un comentario. En la celda de código a continuación, impriman la frase anterior u otra y coméntenlo en la misma línea de código.

# %% [markdown]
# c. Escribir la fecha de hoy usando la función `print()`

# %%
print("Viernes 22 de agosto de 2025")
# Out:
# Viernes 22 de agosto de 2025

# %%
print("22/08/2025")
# Out:
# 22/08/2025

# %%
print("22", "/", "08", "/", "2025")
# Out:
# 22 / 08 / 2025

# %%
print(22, "/", 8, "/", 2025)
# Out:
# 22 / 8 / 2025

# %%
print(22/8/2025)
# Out:
# 0.0013580246913580246
